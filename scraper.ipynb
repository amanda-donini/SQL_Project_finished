# %%
import re
import numpy as np
import pandas as pd
from pandas import json_normalize
import requests
import requests
from bs4 import BeautifulSoup

# %%
pd.set_option('display.max_columns', None)

# %%
schools = {   
'ironhack' : 10828,
'app-academy' : 10525, 
'brainstation' : 10571,
'udacity' : 11118,
'design-sprint-school' : 10698,
'neoland' : 10906,
'ux-design-institute' : 11150,
'careerfoundry' : 10581,
'springboard' : 11035,
'codesmith' : 10643,
'devmountain' : 10710,
'le-wagon' : 10868,
'tech-elevator' : 11056,
'hack-reactor' : 10788,
'fullstack-academy' : 10751,
'the-tech-academy' : 11091,
'bloomtech' : 10854  
}


def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# brainstation
# udacity
# design-sprint-school
# neoland
# ux-design-institute
# careerfoundry
# springboard
# codesmith
# devmountain
# le-wagon
# tech-elevator
# hack-reactor
# fullstack-academy
# the-tech-academy
# bloomtech

# %%
# adding the school_id column
comments['school_id'] = [schools[row] for row in comments.school if row in schools.keys()]

# %%
comments
# Out:
#          id            name  anonymous  hostProgramName  graduatingYear  \
# 0    306372   Sergio Burgos      False             None          2023.0
# 1    306215       Anonymous       True             None          2023.0
# 2    306068       Anonymous       True             None          2023.0
# 3    305297     Utku Cikmaz      False             None          2023.0
# 4    305278    Nirmal Hodge      False             None          2023.0
# ..      ...             ...        ...              ...             ...
# 192  235672   William Terry      False  Web Development          2017.0
# 193  235716  Marcus Latimer      False             None          2017.0
# 194  235713     Steve Booth      False     UX/UI Design          2017.0
# 195  235671  Branden Tucker      False             None          2017.0
# 196  235700     Aidan Mills      False             None          2017.0
#
#     isAlumni                  jobTitle  \
# 0      False  International Negotiator
# 1       True
# 2      False    Full stack development
# 3      False  Full Stack Web Developer
# 4      False          Product Designer
# ..       ...                       ...
# 192     True         Website Developer
# 193     True          Systems Engineer
# 194     True      Web Designer /Artist
# 195     True       Front End Developer
# 196     True             Web Developer
#
#                                             tagline  \
# 0               The Most Intense Academic Challenge
# 1    Transformative Experience: My Time at Ironhack
# 2                                   Now I can do it
# 3                                       It was good
# 4                           Ironhack 100% Worth It!
# ..                                              ...
# 192                Best bootcamp for web developers
# 193                         Phenomenal in every way
# 194         Turn anything you know turns into skill
# 195                             Challenging but fun
# 196                                  Great Teachers
#
#                                                   body  \
# 0    <span class="truncatable"><p></p><p>After comp...
# 1    <span class="truncatable"><p></p><p>Pros: 1)In...
# 2    <span class="truncatable"><p></p><p>7 months a...
# 3    <span class="truncatable"><p></p><p>The course...
# 4    <span class="truncatable"><p></p><p>I joined t...
# ..                                                 ...
# 192  <span class="truncatable"><p>I went to Lambda ...
# 193  <span class="truncatable"><p>I am a person wit...
# 194  <span class="truncatable"><p>Art is my passion...
# 195  <span class="truncatable"><p>I have had a fair...
# 196  <span class="truncatable"><p>I majored in Crim...
#
#                                                rawBody   createdAt  \
# 0    <p>After completing my Data Analytics Bootcamp...  11/10/2023
# 1    <p>Pros: 1)Intensive Learning 2)Real-World Pro...   11/6/2023
# 2    <p>7 months ago, I only had an idea about html...  10/31/2023
# 3    <p>The course was great. Especially, Luis is a...   10/2/2023
# 4    <p>I joined the UX/ UI Bootcamp and to be hone...   9/30/2023
# ..                                                 ...         ...
# 192  I went to Lambda School to improve little skil...   4/20/2017
# 193  I am a person with a mediocre background in co...   4/20/2017
# 194  Art is my passion. I always was fascinated abo...   4/19/2017
# 195  I have had a fair bit of experience with compu...   4/19/2017
# 196  I majored in Criminal Justice from University ...   4/19/2017
#
#       queryDate                   program             user overallScore  \
# 0    2023-11-10   Data Analytics Bootcamp  {'image': None}          3.3
# 1    2023-11-06  Web Development Bootcamp  {'image': None}          4.0
# 2    2023-10-31                      None  {'image': None}          5.0
# 3    2023-10-02  Web Development Bootcamp  {'image': None}          4.0
# 4    2023-09-30     UX/UI Design Bootcamp  {'image': None}          5.0
# ..          ...                       ...              ...          ...
# 192  2017-04-20                      None  {'image': None}          5.0
# 193  2017-04-20                      None  {'image': None}          5.0
# 194  2017-04-19                      None  {'image': None}          4.3
# 195  2017-04-19                      None  {'image': None}          3.7
# 196  2017-04-19                      None  {'image': None}          5.0
#
#     comments overall curriculum jobSupport  \
# 0         []     3.0        3.0        4.0
# 1         []     4.0        4.0        4.0
# 2         []     5.0        5.0        5.0
# 3         []     5.0        3.0        4.0
# 4         []     5.0        5.0        5.0
# ..       ...     ...        ...        ...
# 192       []     5.0        5.0        5.0
# 193       []     5.0        5.0        5.0
# 194       []     4.0        5.0        4.0
# 195       []     4.0        4.0        3.0
# 196       []     5.0        5.0        5.0
#
#                                            review_body     school  school_id
# 0    After completing my Data Analytics Bootcamp wi...   ironhack      10828
# 1    Pros: 1)Intensive Learning 2)Real-World Projec...   ironhack      10828
# 2    7 months ago, I only had an idea about html an...   ironhack      10828
# 3    The course was great. Especially, Luis is a gr...   ironhack      10828
# 4    I joined the UX/ UI Bootcamp and to be honest ...   ironhack      10828
# ..                                                 ...        ...        ...
# 192  I went to Lambda School to improve little skil...  bloomtech      10854
# 193  I am a person with a mediocre background in co...  bloomtech      10854
# 194  Art is my passion. I always was fascinated abo...  bloomtech      10854
# 195  I have had a fair bit of experience with compu...  bloomtech      10854
# 196  I majored in Criminal Justice from University ...  bloomtech      10854
#
# [10722 rows x 22 columns]

# %%
comments.shape
# Out:
# (10722, 22)

# %%
comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10722 entries, 0 to 196
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               10722 non-null  int64
#  1   name             10722 non-null  object
#  2   anonymous        10722 non-null  bool
#  3   hostProgramName  4671 non-null   object
#  4   graduatingYear   10670 non-null  float64
#  5   isAlumni         10710 non-null  object
#  6   jobTitle         6287 non-null   object
#  7   tagline          10721 non-null  object
#  8   body             10722 non-null  object
#  9   rawBody          10722 non-null  object
#  10  createdAt        10722 non-null  object
#  11  queryDate        10722 non-null  object
#  12  program          9430 non-null   object
#  13  user             10722 non-null  object
#  14  overallScore     10710 non-null  object
#  15  comments         10722 non-null  object
#  16  overall          10708 non-null  object
#  17  curriculum       10495 non-null  object
#  18  jobSupport       9931 non-null   object
#  19  review_body      10722 non-null  object
#  20  school           10722 non-null  object
#  21  school_id        10722 non-null  int64
# dtypes: bool(1), float64(1), int64(2), object(18)
# memory usage: 1.8+ MB

# %%
non_nul_comments = [i for i in comments.comments if len(i)>0]
len(non_nul_comments)
# Out:
# 206

# %%
clean_comments = comments.drop(columns=['hostProgramName','body','rawBody','user','comments','queryDate',])
clean_comments.reset_index().drop(columns='index')
clean_comments
# Out:
#          id            name  anonymous  graduatingYear isAlumni  \
# 0    306372   Sergio Burgos      False          2023.0    False
# 1    306215       Anonymous       True          2023.0     True
# 2    306068       Anonymous       True          2023.0    False
# 3    305297     Utku Cikmaz      False          2023.0    False
# 4    305278    Nirmal Hodge      False          2023.0    False
# ..      ...             ...        ...             ...      ...
# 192  235672   William Terry      False          2017.0     True
# 193  235716  Marcus Latimer      False          2017.0     True
# 194  235713     Steve Booth      False          2017.0     True
# 195  235671  Branden Tucker      False          2017.0     True
# 196  235700     Aidan Mills      False          2017.0     True
#
#                      jobTitle                                         tagline  \
# 0    International Negotiator             The Most Intense Academic Challenge
# 1                              Transformative Experience: My Time at Ironhack
# 2      Full stack development                                 Now I can do it
# 3    Full Stack Web Developer                                     It was good
# 4            Product Designer                         Ironhack 100% Worth It!
# ..                        ...                                             ...
# 192         Website Developer                Best bootcamp for web developers
# 193          Systems Engineer                         Phenomenal in every way
# 194      Web Designer /Artist         Turn anything you know turns into skill
# 195       Front End Developer                             Challenging but fun
# 196             Web Developer                                  Great Teachers
#
#       createdAt                   program overallScore overall curriculum  \
# 0    11/10/2023   Data Analytics Bootcamp          3.3     3.0        3.0
# 1     11/6/2023  Web Development Bootcamp          4.0     4.0        4.0
# 2    10/31/2023                      None          5.0     5.0        5.0
# 3     10/2/2023  Web Development Bootcamp          4.0     5.0        3.0
# 4     9/30/2023     UX/UI Design Bootcamp          5.0     5.0        5.0
# ..          ...                       ...          ...     ...        ...
# 192   4/20/2017                      None          5.0     5.0        5.0
# 193   4/20/2017                      None          5.0     5.0        5.0
# 194   4/19/2017                      None          4.3     4.0        5.0
# 195   4/19/2017                      None          3.7     4.0        4.0
# 196   4/19/2017                      None          5.0     5.0        5.0
#
#     jobSupport                                        review_body     school  \
# 0          4.0  After completing my Data Analytics Bootcamp wi...   ironhack
# 1          4.0  Pros: 1)Intensive Learning 2)Real-World Projec...   ironhack
# 2          5.0  7 months ago, I only had an idea about html an...   ironhack
# 3          4.0  The course was great. Especially, Luis is a gr...   ironhack
# 4          5.0  I joined the UX/ UI Bootcamp and to be honest ...   ironhack
# ..         ...                                                ...        ...
# 192        5.0  I went to Lambda School to improve little skil...  bloomtech
# 193        5.0  I am a person with a mediocre background in co...  bloomtech
# 194        4.0  Art is my passion. I always was fascinated abo...  bloomtech
# 195        3.0  I have had a fair bit of experience with compu...  bloomtech
# 196        5.0  I majored in Criminal Justice from University ...  bloomtech
#
#      school_id
# 0        10828
# 1        10828
# 2        10828
# 3        10828
# 4        10828
# ..         ...
# 192      10854
# 193      10854
# 194      10854
# 195      10854
# 196      10854
#
# [10722 rows x 16 columns]

# %%
clean_comments.isna().sum()
# Out:
# id                0
# name              0
# anonymous         0
# graduatingYear    0
# isAlumni          0
# jobTitle          0
# tagline           0
# createdAt         0
# program           0
# overallScore      0
# overall           0
# curriculum        0
# jobSupport        0
# review_body       0
# school            0
# school_id         0
# dtype: int64

# %%
# NANs
clean_comments.dropna(thresh=round(0.8*clean_comments.shape[1]), inplace=True)

# %%
#"Regarding the 'graduatingYear' feature: To maintain the date datatype for this feature, we have dropped all the null values in this column. If the NaN values
# were filled in with the term 'not specified,' Python would convert the data type of this feature to an object, which is not preferable."
clean_comments.dropna(subset=['graduatingYear'],inplace=True)

# %%
# By applying the same tationale to isAlumni feature
clean_comments.dropna(subset=['isAlumni'],inplace=True)

# %%
#First fill in all the empty values with nan
clean_comments = clean_comments.replace(r'^\s*$', np.nan, regex=True)
# Jobtitle nan values are filled in with 'Not specified' term
clean_comments['jobTitle'].fillna('Not specified', inplace=True)
# The same story goes with the program
clean_comments['program'].fillna('Not specified', inplace=True)
#The same story goes with the tagline
clean_comments['tagline'].fillna('Not specified', inplace=True)

# %%
# To fill in the nan values in four score columns, first the values should convered to float
clean_comments['overallScore'] = clean_comments['overallScore'].astype('float')
clean_comments['overall'] = clean_comments['overall'].astype('float')
clean_comments['curriculum'] = clean_comments['curriculum'].astype('float')
clean_comments['jobSupport'] = clean_comments['jobSupport'].astype('float')

# %%
#Then we replaced all the nan values with the median of all the available values for that variable 
#in the corresponding school
fill_na_by_schools = clean_comments.groupby('school')
clean_comments['overallScore'] = fill_na_by_schools['overallScore'].transform(lambda x: x.fillna(x.median()))
clean_comments['overall'] = fill_na_by_schools['overall'].transform(lambda x: x.fillna(x.median()))
clean_comments['curriculum'] = fill_na_by_schools['curriculum'].transform(lambda x: x.fillna(x.median()))
clean_comments['jobSupport'] = fill_na_by_schools['jobSupport'].transform(lambda x: x.fillna(x.median()))

# %%
clean_comments
# Out:
#          id            name  anonymous  graduatingYear  isAlumni  \
# 0    306372   Sergio Burgos      False          2023.0     False
# 1    306215       Anonymous       True          2023.0      True
# 2    306068       Anonymous       True          2023.0     False
# 3    305297     Utku Cikmaz      False          2023.0     False
# 4    305278    Nirmal Hodge      False          2023.0     False
# ..      ...             ...        ...             ...       ...
# 192  235672   William Terry      False          2017.0      True
# 193  235716  Marcus Latimer      False          2017.0      True
# 194  235713     Steve Booth      False          2017.0      True
# 195  235671  Branden Tucker      False          2017.0      True
# 196  235700     Aidan Mills      False          2017.0      True
#
#                      jobTitle                                         tagline  \
# 0    International Negotiator             The Most Intense Academic Challenge
# 1               Not specified  Transformative Experience: My Time at Ironhack
# 2      Full stack development                                 Now I can do it
# 3    Full Stack Web Developer                                     It was good
# 4            Product Designer                         Ironhack 100% Worth It!
# ..                        ...                                             ...
# 192         Website Developer                Best bootcamp for web developers
# 193          Systems Engineer                         Phenomenal in every way
# 194      Web Designer /Artist         Turn anything you know turns into skill
# 195       Front End Developer                             Challenging but fun
# 196             Web Developer                                  Great Teachers
#
#       createdAt                   program  overallScore  overall  curriculum  \
# 0    11/10/2023   Data Analytics Bootcamp           3.3      3.0         3.0
# 1     11/6/2023  Web Development Bootcamp           4.0      4.0         4.0
# 2    10/31/2023             Not specified           5.0      5.0         5.0
# 3     10/2/2023  Web Development Bootcamp           4.0      5.0         3.0
# 4     9/30/2023     UX/UI Design Bootcamp           5.0      5.0         5.0
# ..          ...                       ...           ...      ...         ...
# 192   4/20/2017             Not specified           5.0      5.0         5.0
# 193   4/20/2017             Not specified           5.0      5.0         5.0
# 194   4/19/2017             Not specified           4.3      4.0         5.0
# 195   4/19/2017             Not specified           3.7      4.0         4.0
# 196   4/19/2017             Not specified           5.0      5.0         5.0
#
#      jobSupport                                        review_body     school  \
# 0           4.0  After completing my Data Analytics Bootcamp wi...   ironhack
# 1           4.0  Pros: 1)Intensive Learning 2)Real-World Projec...   ironhack
# 2           5.0  7 months ago, I only had an idea about html an...   ironhack
# 3           4.0  The course was great. Especially, Luis is a gr...   ironhack
# 4           5.0  I joined the UX/ UI Bootcamp and to be honest ...   ironhack
# ..          ...                                                ...        ...
# 192         5.0  I went to Lambda School to improve little skil...  bloomtech
# 193         5.0  I am a person with a mediocre background in co...  bloomtech
# 194         4.0  Art is my passion. I always was fascinated abo...  bloomtech
# 195         3.0  I have had a fair bit of experience with compu...  bloomtech
# 196         5.0  I majored in Criminal Justice from University ...  bloomtech
#
#      school_id
# 0        10828
# 1        10828
# 2        10828
# 3        10828
# 4        10828
# ..         ...
# 192      10854
# 193      10854
# 194      10854
# 195      10854
# 196      10854
#
# [10594 rows x 16 columns]

# %%
clean_comments.dtypes
# Out:
# id                  int64
# name               object
# anonymous            bool
# graduatingYear    float64
# isAlumni             bool
# jobTitle           object
# tagline            object
# createdAt          object
# program            object
# overallScore      float64
# overall           float64
# curriculum        float64
# jobSupport        float64
# review_body        object
# school             object
# school_id           int64
# dtype: object

# %%
#to use the data frame in another .ipynb file
# %store clean_comments
# Out:
# Stored 'clean_comments' (DataFrame)

# %%
def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# app-academy
# brainstation
# udacity
# design-sprint-school
# neoland
# ux-design-institute
# careerfoundry
# springboard
# codesmith
# devmountain
# le-wagon
# tech-elevator
# hack-reactor
# fullstack-academy
# the-tech-academy
# bloomtech

# %%
locations = pd.concat(locations_list)
locations
# Out:
#        id                      description  country.id   country.name  \
# 0   15901                  Berlin, Germany        57.0        Germany
# 1   16022              Mexico City, Mexico        29.0         Mexico
# 2   16086           Amsterdam, Netherlands        59.0    Netherlands
# 3   16088                Sao Paulo, Brazil        42.0         Brazil
# 4   16109                    Paris, France        38.0         France
# ..    ...                              ...         ...            ...
# 6   17372  Jacksonville, FL, United States         1.0  United States
# 7   17373   Baton Rouge, LA, United States         1.0  United States
# 0   15729      Portland, OR, United States         1.0  United States
# 1   16404                           Online         NaN            NaN
# 0   15993                           Online         NaN            NaN
#
#    country.abbrev  city.id     city.name  city.keyword  state.id state.name  \
# 0              DE  31156.0        Berlin        berlin       NaN        NaN
# 1              MX  31175.0   Mexico City   mexico-city       NaN        NaN
# 2              NL  31168.0     Amsterdam     amsterdam       NaN        NaN
# 3              BR  31121.0     Sao Paulo     sao-paulo       NaN        NaN
# 4              FR  31136.0         Paris         paris       NaN        NaN
# ..            ...      ...           ...           ...       ...        ...
# 6              US     30.0  Jacksonville  jacksonville      11.0    Florida
# 7              US     46.0   Baton Rouge   baton-rouge      20.0  Louisiana
# 0              US     76.0      Portland      portland      39.0     Oregon
# 1             NaN      NaN           NaN           NaN       1.0     Online
# 0             NaN      NaN           NaN           NaN       1.0     Online
#
#    state.abbrev state.keyword             school  school_id
# 0           NaN           NaN           ironhack      10828
# 1           NaN           NaN           ironhack      10828
# 2           NaN           NaN           ironhack      10828
# 3           NaN           NaN           ironhack      10828
# 4           NaN           NaN           ironhack      10828
# ..          ...           ...                ...        ...
# 6            FL       florida  fullstack-academy      10751
# 7            LA     louisiana  fullstack-academy      10751
# 0            OR        oregon   the-tech-academy      11091
# 1        Online        online   the-tech-academy      11091
# 0        Online        online          bloomtech      10854
#
# [99 rows x 14 columns]

# %%
locations.shape
# Out:
# (99, 14)

# %%
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 0
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              99 non-null     int64
#  1   description     99 non-null     object
#  2   country.id      99 non-null     object
#  3   country.name    99 non-null     object
#  4   country.abbrev  99 non-null     object
#  5   city.id         99 non-null     object
#  6   city.name       99 non-null     object
#  7   city.keyword    99 non-null     object
#  8   state.id        99 non-null     object
#  9   state.name      99 non-null     object
#  10  state.abbrev    99 non-null     object
#  11  state.keyword   99 non-null     object
#  12  school          99 non-null     object
#  13  school_id       99 non-null     int64
# dtypes: int64(2), object(12)
# memory usage: 11.6+ KB

# %%
locations.fillna('not applicable',inplace=True)

# %%
courses = pd.concat(courses_list)
courses
# Out:
#                                       courses            school  school_id
# 0                     Cyber Security Bootcamp          ironhack      10828
# 1                     Cybersecurity Part-Time          ironhack      10828
# 2                     Data Analytics Bootcamp          ironhack      10828
# 3                    Data Analytics Part-Time          ironhack      10828
# 4                       UX/UI Design Bootcamp          ironhack      10828
# ..                                        ...               ...        ...
# 32        Self-Paced UI/UX Designer Boot Camp  the-tech-academy      11091
# 0   Free Coding Course: Intro to HTML and CSS         bloomtech      10854
# 1               Full Time Backend Development         bloomtech      10854
# 2                      Full Time Data Science         bloomtech      10854
# 3        Full Time Full Stack Web Development         bloomtech      10854
#
# [185 rows x 3 columns]

# %%
courses.shape
# Out:
# (185, 3)

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   courses    185 non-null    object
#  1   school     185 non-null    object
#  2   school_id  185 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 5.8+ KB

# %%
badges = pd.concat(badges_list)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3   VET TEC Provider   vet_tec_provider
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3   VET TEC Provider   vet_tec_provider
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
#
#                                          description                school  \
# 0          <p>School offers fully online courses</p>              ironhack
# 1  <p>School publishes a third-party verified out...              ironhack
# 2  <p>School offers part-time and evening classes...              ironhack
# 0          <p>School offers fully online courses</p>           app-academy
# 1  <p>School offers part-time and evening classes...           app-academy
# 2             <p>School guarantees job placement</p>           app-academy
# 0          <p>School offers fully online courses</p>          brainstation
# 1  <p>School offers part-time and evening classes...          brainstation
# 2                  <p>School accepts the GI Bill</p>          brainstation
# 0          <p>School offers fully online courses</p>               udacity
# 1  <p>School offers part-time and evening classes...               udacity
# 0          <p>School offers fully online courses</p>  design-sprint-school
# 1  <p>School offers part-time and evening classes...  design-sprint-school
# 0          <p>School offers fully online courses</p>               neoland
# 1  <p>School offers part-time and evening classes...               neoland
# 0          <p>School offers fully online courses</p>   ux-design-institute
# 1  <p>School offers part-time and evening classes...   ux-design-institute
# 0          <p>School offers fully online courses</p>         careerfoundry
# 1  <p>School offers part-time and evening classes...         careerfoundry
# 2             <p>School guarantees job placement</p>         careerfoundry
# 0          <p>School offers fully online courses</p>           springboard
# 1  <p>School offers part-time and evening classes...           springboard
# 2             <p>School guarantees job placement</p>           springboard
# 0          <p>School offers fully online courses</p>             codesmith
# 1  <p>School publishes a third-party verified out...             codesmith
# 2  <p>School offers part-time and evening classes...             codesmith
# 0          <p>School offers fully online courses</p>           devmountain
# 1  <p>School offers part-time and evening classes...           devmountain
# 0          <p>School offers fully online courses</p>              le-wagon
# 1  <p>School offers part-time and evening classes...              le-wagon
# 0          <p>School offers fully online courses</p>         tech-elevator
# 1  <p>School publishes a third-party verified out...         tech-elevator
# 2  <p>School offers part-time and evening classes...         tech-elevator
# 3                  <p>School accepts the GI Bill</p>         tech-elevator
# 0          <p>School offers fully online courses</p>          hack-reactor
# 1  <p>School publishes a third-party verified out...          hack-reactor
# 2  <p>School offers part-time and evening classes...          hack-reactor
# 3                <p>School is a VET TEC Provider</p>          hack-reactor
# 0          <p>School offers fully online courses</p>     fullstack-academy
# 1  <p>School publishes a third-party verified out...     fullstack-academy
# 2  <p>School offers part-time and evening classes...     fullstack-academy
# 3                <p>School is a VET TEC Provider</p>     fullstack-academy
# 0          <p>School offers fully online courses</p>      the-tech-academy
# 1  <p>School publishes a third-party verified out...      the-tech-academy
# 2  <p>School offers part-time and evening classes...      the-tech-academy
# 0          <p>School offers fully online courses</p>             bloomtech
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 0      10525
# 1      10525
# 2      10525
# 0      10571
# 1      10571
# 2      10571
# 0      11118
# 1      11118
# 0      10698
# 1      10698
# 0      10906
# 1      10906
# 0      11150
# 1      11150
# 0      10581
# 1      10581
# 2      10581
# 0      11035
# 1      11035
# 2      11035
# 0      10643
# 1      10643
# 2      10643
# 0      10710
# 1      10710
# 0      10868
# 1      10868
# 0      11056
# 1      11056
# 2      11056
# 3      11056
# 0      10788
# 1      10788
# 2      10788
# 3      10788
# 0      10751
# 1      10751
# 2      10751
# 3      10751
# 0      11091
# 1      11091
# 2      11091
# 0      10854

# %%
def remove_tags(x):
        TAG_RE = re.compile(r'<[^>]+>')
        return TAG_RE.sub('',x)

# %%
badges['description'] = badges['description'].apply(remove_tags)
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 2      Job Guarantee      job_guarantee
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3    Accepts GI Bill    accepts_gi_bill
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3   VET TEC Provider   vet_tec_provider
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 3   VET TEC Provider   vet_tec_provider
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
#
#                                          description                school  \
# 0                 School offers fully online courses              ironhack
# 1  School publishes a third-party verified outcom...              ironhack
# 2        School offers part-time and evening classes              ironhack
# 0                 School offers fully online courses           app-academy
# 1        School offers part-time and evening classes           app-academy
# 2                    School guarantees job placement           app-academy
# 0                 School offers fully online courses          brainstation
# 1        School offers part-time and evening classes          brainstation
# 2                         School accepts the GI Bill          brainstation
# 0                 School offers fully online courses               udacity
# 1        School offers part-time and evening classes               udacity
# 0                 School offers fully online courses  design-sprint-school
# 1        School offers part-time and evening classes  design-sprint-school
# 0                 School offers fully online courses               neoland
# 1        School offers part-time and evening classes               neoland
# 0                 School offers fully online courses   ux-design-institute
# 1        School offers part-time and evening classes   ux-design-institute
# 0                 School offers fully online courses         careerfoundry
# 1        School offers part-time and evening classes         careerfoundry
# 2                    School guarantees job placement         careerfoundry
# 0                 School offers fully online courses           springboard
# 1        School offers part-time and evening classes           springboard
# 2                    School guarantees job placement           springboard
# 0                 School offers fully online courses             codesmith
# 1  School publishes a third-party verified outcom...             codesmith
# 2        School offers part-time and evening classes             codesmith
# 0                 School offers fully online courses           devmountain
# 1        School offers part-time and evening classes           devmountain
# 0                 School offers fully online courses              le-wagon
# 1        School offers part-time and evening classes              le-wagon
# 0                 School offers fully online courses         tech-elevator
# 1  School publishes a third-party verified outcom...         tech-elevator
# 2        School offers part-time and evening classes         tech-elevator
# 3                         School accepts the GI Bill         tech-elevator
# 0                 School offers fully online courses          hack-reactor
# 1  School publishes a third-party verified outcom...          hack-reactor
# 2        School offers part-time and evening classes          hack-reactor
# 3                       School is a VET TEC Provider          hack-reactor
# 0                 School offers fully online courses     fullstack-academy
# 1  School publishes a third-party verified outcom...     fullstack-academy
# 2        School offers part-time and evening classes     fullstack-academy
# 3                       School is a VET TEC Provider     fullstack-academy
# 0                 School offers fully online courses      the-tech-academy
# 1  School publishes a third-party verified outcom...      the-tech-academy
# 2        School offers part-time and evening classes      the-tech-academy
# 0                 School offers fully online courses             bloomtech
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 0      10525
# 1      10525
# 2      10525
# 0      10571
# 1      10571
# 2      10571
# 0      11118
# 1      11118
# 0      10698
# 1      10698
# 0      10906
# 1      10906
# 0      11150
# 1      11150
# 0      10581
# 1      10581
# 2      10581
# 0      11035
# 1      11035
# 2      11035
# 0      10643
# 1      10643
# 2      10643
# 0      10710
# 1      10710
# 0      10868
# 1      10868
# 0      11056
# 1      11056
# 2      11056
# 3      11056
# 0      10788
# 1      10788
# 2      10788
# 3      10788
# 0      10751
# 1      10751
# 2      10751
# 3      10751
# 0      11091
# 1      11091
# 2      11091
# 0      10854

# %%
badges.shape
# Out:
# (46, 5)

# %%
badges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         46 non-null     object
#  1   keyword      46 non-null     object
#  2   description  46 non-null     object
#  3   school       46 non-null     object
#  4   school_id    46 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    brainstation.io
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0                         www.designsprintschool.com
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>Founded in 2012, ...
# 0  <span class="truncatable"><p>BrainStation is t...
# 0  <span class="truncatable"><p>Udacity is the tr...
# 0  <span class="truncatable"><p>The best program ...
#
#                                              LogoUrl                school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...           app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          brainstation
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...               udacity
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  design-sprint-school
#
#    school_id
# 0      10828
# 0      10525
# 0      10571
# 0      11118
# 0      10698

# %%
schools['description'] = schools['description'].apply(remove_tags)

schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    brainstation.io
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
# 0                         www.designsprintschool.com
#
#                                          description  \
# 0  Ironhack is a global tech school with 9 campus...
# 0  Founded in 2012, App Academy is a world-renown...
# 0  BrainStation is the global leader in digital s...
# 0  Udacity is the trusted market leader in talent...
# 0  The best program to learn and practice online ...
#
#                                              LogoUrl                school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...           app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          brainstation
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...               udacity
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  design-sprint-school
#
#    school_id
# 0      10828
# 0      10525
# 0      10571
# 0      11118
# 0      10698

# %%
def scrape_school_info(school):
    courses_data = []
    url = f"https://www.switchup.org/bootcamps/{school}"

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Encontrando a seção de cursos
    courses_sections = soup.find_all('div', class_="course")

    for section in courses_sections:
        # Extraindo o nome do curso
        course_name = section.find('h4').text.strip()
        try:
            course_cost = section.find('div', class_="cost").find('span')
        except AttributeError as ae:
            course_cost = "NA"
        have_cost = len(section.find('div', class_="course__datapoints").find_all("div"))
        if have_cost > 1:
            course_duration = str(section.find('div', class_="course__datapoints").find_all("div")[1]).replace("<div> <strong>Duration:</strong>", "").replace("<span>", "").replace("</span> </div>", "")
        else:
            course_duration = "NA"

        courses_data.append({
            'school_name': school,
            'course_name': course_name,
            'duration': course_duration,
            'cost': course_cost
        })

    return courses_data

# school_names = ['flatiron-school']  # Adicione mais escolas conforme necessário\
school_names = ['ironhack', 'app-academy', 'brainstation', 'udacity', 'design-sprint-school', 'neoland', 'ux-design-institute', 'careerfoundry', 'springboard', 'codesmith', 'devmountain', 'le-wagon', 'tech-elevator', 'hack-reactor', 'fullstack-academy', 'the-tech-academy', 'bloomtech']

all_courses = []

for school in school_names:
    school_courses = scrape_school_info(school)
    all_courses.extend(school_courses)

costs = pd.DataFrame(all_courses)
costs
# Out:
#           school_name                                course_name   duration  \
# 0            ironhack                   Web Development Bootcamp    9 weeks
# 1            ironhack                  Web Development Part-Time   24 weeks
# 2            ironhack                      UX/UI Design Bootcamp    9 weeks
# 3            ironhack                     UX/UI Design Part-Time   24 weeks
# 4            ironhack                    Cyber Security Bootcamp   12 weeks
# ..                ...                                        ...        ...
# 112  the-tech-academy     Full-Time Software Developer Boot Camp   22 weeks
# 113         bloomtech  Free Coding Course: Intro to HTML and CSS         NA
# 114         bloomtech              Full Time Backend Development   36 weeks
# 115         bloomtech                     Full Time Data Science   24 weeks
# 116         bloomtech       Full Time Full Stack Web Development   24 weeks
#
#              cost
# 0    [ $12,000  ]
# 1    [ $13,000  ]
# 2    [ $12,000  ]
# 3    [ $13,000  ]
# 4     [ €7,500  ]
# ..            ...
# 112  [ $11,660  ]
# 113        [Free]
# 114  [ $21,950  ]
# 115  [ $21,950  ]
# 116  [ $21,950  ]
#
# [117 rows x 4 columns]

# %%
costs.shape
# Out:
# (117, 4)

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school_name  117 non-null    object
#  1   course_name  117 non-null    object
#  2   duration     117 non-null    object
#  3   cost         117 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
costs['cost'] = costs['cost'].astype('str')

# %%
costs['cost'] = costs['cost'].apply(remove_tags)

# %%
costs['cost'] = costs['cost'].apply(lambda x: x.strip())

# %%
costs['cost'] = costs['cost'].apply(lambda x: ''.join(char for char in x if char.isdigit()))
costs['cost'] = costs['cost'].apply(lambda x: 0 if x=='' else x)

# %%
costs['cost'] = costs['cost'].astype('int')

# %%
costs['duration'] = costs['duration'].apply(lambda x: x.replace('NA','not specified'))

# %%
costs.course_name.value_counts()
# Out:
# course_name
# Web Development Bootcamp                2
# UX/UI Design Bootcamp                   2
# UX/UI Design Part-Time                  2
# Front-End Web Development               2
# Data Science Bootcamp                   2
#                                        ..
# Live Online Design Sprint Experience    1
# Cloud Dev Ops Engineer                  1
# C++                                     1
# Business Analytics                      1
# Full Time Full Stack Web Development    1
# Name: count, Length: 112, dtype: int64

# %%
costs['school_id'] = [schools[row] for row in costs['school_name'] if row in schools.keys()]

# %%
costs
# Out:
#           school_name                                course_name  \
# 0            ironhack                   Web Development Bootcamp
# 1            ironhack                  Web Development Part-Time
# 2            ironhack                      UX/UI Design Bootcamp
# 3            ironhack                     UX/UI Design Part-Time
# 4            ironhack                    Cyber Security Bootcamp
# ..                ...                                        ...
# 112  the-tech-academy     Full-Time Software Developer Boot Camp
# 113         bloomtech  Free Coding Course: Intro to HTML and CSS
# 114         bloomtech              Full Time Backend Development
# 115         bloomtech                     Full Time Data Science
# 116         bloomtech       Full Time Full Stack Web Development
#
#           duration   cost  school_id
# 0          9 weeks  12000      10828
# 1         24 weeks  13000      10828
# 2          9 weeks  12000      10828
# 3         24 weeks  13000      10828
# 4         12 weeks   7500      10828
# ..             ...    ...        ...
# 112       22 weeks  11660      11091
# 113  not specified      0      10854
# 114       36 weeks  21950      10854
# 115       24 weeks  21950      10854
# 116       24 weeks  21950      10854
#
# [117 rows x 5 columns]

# %%
set1 = set(costs['course_name'])
set2 = set(courses['courses'])
common_elements = set1.intersection(set2)
unique_to_list2 = set2.difference(set1)

print(f"Common elements: {len(common_elements)} and set1:{len(set1)} and set2:{len(set2)}")
print(unique_to_list2)
# Out:
# Common elements: 112 and set1:112 and set2:179
# {'Python for Web Developers Course', 'Intro to UX Design Course', 'Self-Paced C# and .NET Framework Boot Camp', 'UX Career Track', 'Java Developer', 'Social Media Marketing Course', 'Self-Paced Python Developer Boot Camp', 'Part-Time Front-End Web Developer Boot Camp', 'Part-Time Game Developer Boot Camp', 'Full-Time UI/UX Designer Boot Camp', 'iOS Developer', 'Self-Paced Software Developer Boot Camp', 'Product Management Program', 'React', 'Marketing Analytics', 'Natural Language Processing', 'Part-Time Data Science Boot Camp', 'User Experience Design | After Hours', 'Self-Paced Front-End Web Developer Boot Camp', 'Predictive Analytics for Business', 'Part-Time JavaScript Developer Boot Camp', 'Introduction to Machine Learning', 'Self-Paced Java and Android Developer Boot Camp', 'Python Course', 'Part-Time Software Developer Boot Camp', 'Part-Time Python Developer Boot Camp', 'Web Development Course', 'Part-Time Mobile App Developer Boot Camp', 'Computer Vision', 'Self-Paced Data Science Boot Camp', 'Search Engine Marketing Course', 'Front End Web Developer', 'Self-Paced Cyber Security Boot Camp', 'Software Engineering Career Track Prep Course', 'Self-Paced UI/UX Designer Boot Camp', 'Deep Reinforcement Learning', 'Part-Time Cyber Security Boot Camp', 'UI for UX Designers Course', 'User Interface Design Course', 'Part-Time C# and .NET Framework Boot Camp', 'Data Structures and Algorithms', 'Robotics Software Engineer', 'Full Stack Web Developer', 'Voice User Interface Design Course', 'Deep Learning', 'Intro to UI Design Course', 'Machine Learning Engineer', 'Part-Time UI/UX Designer Boot Camp', 'UX Designer', 'Part-Time Java and Android Developer Boot Camp', 'Data Engineer', 'User Experience Design Bootcamp', 'Data Analyst', 'UX Design Program', 'Data Visualization', 'Digital Marketing', 'Cloud Developer', 'UI Design Program', 'Introduction to Programming', 'Self-Paced Game Developer Boot Camp', 'Software Engineering Bootcamp', 'Product Management Course', 'Self-Paced JavaScript Developer Boot Camp', 'Self-Driving Car Engineer', 'Self-Paced Mobile App Developer', 'User Experience Design Course', 'UI/UX Design Career Track'}
